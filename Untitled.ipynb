# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv("FiveCoilData.csv")

# %%
data.head()
# Out:
#    I_SEGMENTNR  I_LINE_SPEED  I_COIL_NO  I_RC1_TEMPERATURE  I_RC2_TEMPERATURE  \
# 0            0          20.0      10151          72.440468          67.688354
# 1            1          20.0      10151          72.443176          67.744652
# 2            2          20.0      10151          72.427803          67.830276
# 3            3          20.0      10151          72.409447          67.920326
# 4            4          20.0      10151          72.396645          68.026070
#
#    I_RC3_TEMPERATURE  I_LINEAR_POTENTIOMETER_ENTRY  \
# 0          74.255028                    266.898773
# 1          74.450829                    266.840271
# 2          74.627663                    266.840271
# 3          74.794075                    266.840271
# 4          74.940094                    266.840271
#
#    I_LINEAR_POTENTIOMETER_EXIT         I_DT_TIME
# 0                   257.815094  16-06-2022 07:21
# 1                   257.814758  16-06-2022 07:21
# ...

# %%
data.tail()
# Out:
#      I_SEGMENTNR  I_LINE_SPEED  I_COIL_NO  I_RC1_TEMPERATURE  \
# 694           96     44.219894      99995          68.324768
# 695           97     44.219894      99995          68.294540
# 696           98     44.219894      99995          68.256317
# 697           99     43.805637      99995          68.200417
# 698          100     38.462124      99995          68.171295
#
#      I_RC2_TEMPERATURE  I_RC3_TEMPERATURE  I_LINEAR_POTENTIOMETER_ENTRY  \
# 694          69.058891          75.186043                    171.701401
# 695          69.016342          75.044563                    171.701401
# 696          68.989281          74.897316                    171.701401
# 697          68.963936          74.744423                    171.701401
# 698          68.923027          74.662392                    171.607239
#
#      I_LINEAR_POTENTIOMETER_EXIT         I_DT_TIME
# 694                   172.569443  18-06-2022 04:22
# 695                   172.569443  18-06-2022 04:22
# ...

# %%
data.describe()
# Out:
#        I_SEGMENTNR  I_LINE_SPEED     I_COIL_NO  I_RC1_TEMPERATURE  \
# count   699.000000    699.000000    699.000000         699.000000
# mean     55.227468     37.479247  23134.689557          69.139940
# std      38.232377     12.778056  31609.986591           1.124241
# min       0.000000      0.000000  10093.000000          66.654648
# 25%      23.000000     25.671306  10094.000000          68.685326
# 50%      51.000000     44.779892  10151.000000          69.219353
# 75%      82.000000     46.179886  10299.000000          69.584423
# max     156.000000     50.519867  99995.000000          72.443176
#
#        I_RC2_TEMPERATURE  I_RC3_TEMPERATURE  I_LINEAR_POTENTIOMETER_ENTRY  \
# count         699.000000         699.000000                    699.000000
# mean           68.915393          72.707139                    180.922862
# std             0.949647           1.775610                     40.859944
# min            67.553146          70.115746                    149.379425
# ...

# %%
data.nunique()
# Out:
# I_SEGMENTNR                     157
# I_LINE_SPEED                     96
# I_COIL_NO                         5
# I_RC1_TEMPERATURE               578
# I_RC2_TEMPERATURE               671
# I_RC3_TEMPERATURE               697
# I_LINEAR_POTENTIOMETER_ENTRY    310
# I_LINEAR_POTENTIOMETER_EXIT     152
# I_DT_TIME                       120
# dtype: int64

# %%
data.shape
# Out:
# (699, 9)

# %%
data.isnull().sum()
# Out:
# I_SEGMENTNR                     0
# I_LINE_SPEED                    0
# I_COIL_NO                       0
# I_RC1_TEMPERATURE               0
# I_RC2_TEMPERATURE               0
# I_RC3_TEMPERATURE               0
# I_LINEAR_POTENTIOMETER_ENTRY    0
# I_LINEAR_POTENTIOMETER_EXIT     0
# I_DT_TIME                       0
# dtype: int64

# %%
corelation = data.corr()

# %%
sns.heatmap(corelation, xticklabels=corelation.columns, yticklabels=corelation.columns
           , annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data)

# %%
sns.relplot(x = 'I_LINE_SPEED' , y = 'I_COIL_NO' , hue = 'I_RC1_TEMPERATURE' , data=data)

# %%
sns.relplot(x = 'I_DT_TIME' , y = 'I_LINEAR_POTENTIOMETER_ENTRY' , hue = 'I_COIL_NO' , data=data)

# %%
sns.distplot(data['I_RC1_TEMPERATURE'])
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='I_RC1_TEMPERATURE', ylabel='Density'>

# %%
sns.distplot(data['I_RC2_TEMPERATURE'])
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='I_RC2_TEMPERATURE', ylabel='Density'>

# %%
sns.distplot(data['I_RC3_TEMPERATURE'])
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='I_RC3_TEMPERATURE', ylabel='Density'>

# %%
L
