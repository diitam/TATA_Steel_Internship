# %%
import numpy as np
import seaborn as sns
import pandas as pd

# %%
data = pd.read_csv("FiveCoilData.csv")

# %%
x = np.std(data)
print(x)
# Out:
# I_SEGMENTNR                        38.205019
# I_LINE_SPEED                       12.768913
# I_COIL_NO                       31587.367636
# I_RC1_TEMPERATURE                   1.123437
# I_RC2_TEMPERATURE                   0.948968
# I_RC3_TEMPERATURE                   1.774340
# I_LINEAR_POTENTIOMETER_ENTRY       40.830706
# I_LINEAR_POTENTIOMETER_EXIT        39.002946
# dtype: float64

# %%
x = np.var(data)
print(x)
# Out:
# I_SEGMENTNR                     2054.000000
# I_LINE_SPEED                      94.614303
# I_COIL_NO                          0.000000
# I_RC1_TEMPERATURE                  1.426464
# I_RC2_TEMPERATURE                  0.930071
# I_RC3_TEMPERATURE                  3.533318
# I_LINEAR_POTENTIOMETER_ENTRY    1605.779734
# I_LINEAR_POTENTIOMETER_EXIT     1586.814137
# SR.NO                           2054.000000
# dtype: float64

# %%
x = np.mean(data)
print(x)
# Out:
# I_SEGMENTNR                        55.227468
# I_LINE_SPEED                       37.479247
# I_COIL_NO                       23134.689557
# I_RC1_TEMPERATURE                  69.139940
# I_RC2_TEMPERATURE                  68.915393
# I_RC3_TEMPERATURE                  72.707139
# I_LINEAR_POTENTIOMETER_ENTRY      180.922862
# I_LINEAR_POTENTIOMETER_EXIT       178.467250
# dtype: float64

# %%
correlation = data.corr()

# %%
sns.heatmap(correlation, xticklabels=correlation.columns, yticklabels=correlation.columns
           , annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.relplot(x = 'I_COIL_NO' , y = 'I_LINE_SPEED' , data=data)

# %%
sns.pairplot(data)
